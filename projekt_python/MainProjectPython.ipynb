# %%
#import bibliotek
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import pandas as pd

# %%
#wczytywanie DF z linku https://we.tl/t-yDSAPEXRdB

DF = pd.read_csv('kickstarter_public_kickstarter_filtered.tsv',sep='\t')
DF.head()
# Out:
#            id                                               name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
# 4  1622952265                                         Pantshirts
#
#   main_category      category        country    launched    deadline  \
# 0       Fashion       Fashion  United States  2009-04-21  2009-05-31
# 1  Film & Video        Shorts  United States  2009-04-23  2009-07-20
# 2           Art  Illustration  United States  2009-04-24  2009-05-03
# 3    Technology      Software  United States  2009-04-25  2009-07-14
# 4       Fashion       Fashion  United States  2009-04-27  2009-05-26
#
#    duration currency  goal_in_defined_currency  pledged_in_defined_currency  \
# 0        40      USD                    1000.0                        625.0
# ...

# %%
DF['MC_C']=DF['main_category']+DF['category']
DF.head()
# Out:
#            id                                               name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
# 4  1622952265                                         Pantshirts
#
#   main_category      category        country    launched    deadline  \
# 0       Fashion       Fashion  United States  2009-04-21  2009-05-31
# 1  Film & Video        Shorts  United States  2009-04-23  2009-07-20
# 2           Art  Illustration  United States  2009-04-24  2009-05-03
# 3    Technology      Software  United States  2009-04-25  2009-07-14
# 4       Fashion       Fashion  United States  2009-04-27  2009-05-26
#
#    duration currency  goal_in_defined_currency  pledged_in_defined_currency  \
# 0        40      USD                    1000.0                        625.0
# ...

# %%
DF[['id','main_category','category']].plot.hist(bins=200,alpha=0.5)

# %%
DF_duration=DF['duration']
DF_duration.head
# Out:
# <bound method NDFrame.head of 0         40
# 1         88
# 2          9
# 3         80
# 4         29
#           ..
# 368233    20
# 368234     3
# 368235     5
# 368236    14
# 368237    30
# Name: duration, Length: 368238, dtype: int64>
